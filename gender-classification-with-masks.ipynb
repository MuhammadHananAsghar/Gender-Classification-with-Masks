# %% [markdown]
# # Libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %matplotlib inline

# %% [markdown]
# # DataGenerator

# %%
BATCH = 20
IMG_WIDTH = 96
IMG_HEIGHT = 96

# %%
train_loader = tf.keras.preprocessing.image_dataset_from_directory(
"../input/gender-classified-dataset-with-masked-face/GenderOcclusionData/Training",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=BATCH
)

test_loader = tf.keras.preprocessing.image_dataset_from_directory(
"../input/gender-classified-dataset-with-masked-face/GenderOcclusionData/Validation",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=BATCH
)
# Out:
# Found 72318 files belonging to 2 classes.
# 2022-04-08 03:16:48.902555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:48.994842: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:48.995638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:48.998337: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-08 03:16:48.999105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:48.999839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:49.000486: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:51.097681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:51.098667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:51.099428: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 03:16:51.100115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 16813 files belonging to 2 classes.

# %%
class_names = train_loader.class_names
print(class_names)
# Out:
# ['female', 'male']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_loader.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# 2022-04-08 03:16:56.294211: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_loader.cache().shuffle(500).prefetch(buffer_size=AUTOTUNE)
test_dataset = test_loader.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Model

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(IMG_HEIGHT, 
                                                              IMG_WIDTH,
                                                              3)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

model = tf.keras.models.Sequential([
    data_augmentation,
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
  
    tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(len(class_names))
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 96, 96, 3)         0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 96, 96, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 96, 96, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               589952
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 687,650
# Trainable params: 687,650
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
epochs = 20
history = model.fit(
  train_dataset,
  validation_data=test_dataset,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 2022-04-08 03:17:08.888493: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 272 of 500
# 2022-04-08 03:17:16.865138: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 2022-04-08 03:17:17.699910: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 3616/3616 [==============================] - 190s 46ms/step - loss: 0.4297 - accuracy: 0.7939 - val_loss: 0.3302 - val_accuracy: 0.8603
# Epoch 2/20
# 3616/3616 [==============================] - 24s 7ms/step - loss: 0.2911 - accuracy: 0.8745 - val_loss: 0.2440 - val_accuracy: 0.8983
# Epoch 3/20
# 3616/3616 [==============================] - 23s 6ms/step - loss: 0.2605 - accuracy: 0.8895 - val_loss: 0.2088 - val_accuracy: 0.9107
# Epoch 4/20
# 3616/3616 [==============================] - 24s 7ms/step - loss: 0.2445 - accuracy: 0.8966 - val_loss: 0.2147 - val_accuracy: 0.9104
# Epoch 5/20
# 3616/3616 [==============================] - 24s 7ms/step - loss: 0.2318 - accuracy: 0.9025 - val_loss: 0.1897 - val_accuracy: 0.9207
# Epoch 6/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.2230 - accuracy: 0.9062 - val_loss: 0.1748 - val_accuracy: 0.9262
# Epoch 7/20
# 3616/3616 [==============================] - 24s 7ms/step - loss: 0.2147 - accuracy: 0.9108 - val_loss: 0.1871 - val_accuracy: 0.9240
# Epoch 8/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.2126 - accuracy: 0.9118 - val_loss: 0.1864 - val_accuracy: 0.9237
# Epoch 9/20
# 3616/3616 [==============================] - 23s 6ms/step - loss: 0.2072 - accuracy: 0.9147 - val_loss: 0.1777 - val_accuracy: 0.9251
# Epoch 10/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.2043 - accuracy: 0.9162 - val_loss: 0.1650 - val_accuracy: 0.9311
# Epoch 11/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.2003 - accuracy: 0.9185 - val_loss: 0.1715 - val_accuracy: 0.9304
# Epoch 12/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.1995 - accuracy: 0.9191 - val_loss: 0.1595 - val_accuracy: 0.9342
# Epoch 13/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.1941 - accuracy: 0.9218 - val_loss: 0.1560 - val_accuracy: 0.9355
# Epoch 14/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.1934 - accuracy: 0.9223 - val_loss: 0.1658 - val_accuracy: 0.9390
# Epoch 15/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.1901 - accuracy: 0.9242 - val_loss: 0.1572 - val_accuracy: 0.9365
# Epoch 16/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.1915 - accuracy: 0.9229 - val_loss: 0.1546 - val_accuracy: 0.9364
# Epoch 17/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.1885 - accuracy: 0.9243 - val_loss: 0.1504 - val_accuracy: 0.9384
# Epoch 18/20
# 3616/3616 [==============================] - 25s 7ms/step - loss: 0.1875 - accuracy: 0.9256 - val_loss: 0.1511 - val_accuracy: 0.9381
# Epoch 19/20
# 3616/3616 [==============================] - 26s 7ms/step - loss: 0.1854 - accuracy: 0.9254 - val_loss: 0.1500 - val_accuracy: 0.9404
# Epoch 20/20
# 3616/3616 [==============================] - 26s 7ms/step - loss: 0.1833 - accuracy: 0.9271 - val_loss: 0.1554 - val_accuracy: 0.9381

# %% [markdown]
# # Evaluation

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(test_dataset)
# Out:
# 841/841 [==============================] - 2s 3ms/step - loss: 0.1554 - accuracy: 0.9381

# %%
plt.figure(figsize=(10, 10))
for images, labels in test_loader.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = model.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        plt.ylabel("Predicted: "+class_names[np.argmax(score)])
        plt.title("Actual: "+class_names[labels[i]])
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])

# %% [markdown]
# # Implemented by Muhammad Hanan Asghar
